# %% [markdown]
# ## Final Exam WQD 7005 Data Mining
# ## Question 4
#
# ### Name: Nurullainy binti Mat Rashid
# ### ID :  17036591

# %% [markdown]
# ### Topic: Rule Mining  of Internet Movie Database (IMDb)
#
# The objectives are to find frequent itemsets and mining Associatio Rules using data from IMDb. The data was collected from the following website : https://www.imdb.com/search/title/?year=2017

# %% [markdown]
# In order to achieve the task, I will be going to cover the following steps:
#
#     1) Importing required libraries
#     2) Creating a list from dataset (Question 1)
#     3) Convert list to dataframe with boolean values
#     4) Find frequently occurring itemsets using Apriori Algorithm
#     5) Find frequently occurring itemsets using F-P Growth
#     6) Mine the Association Rules

# %% [markdown]
# ### 1) Importing required libraries

# %%
import pandas as pd
import numpy as np

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

import csv

# %%
# Load dataset

df = pd.read_csv('movies_imdb_preprocessed.csv')
df.head()
# Out:
#             movie_name  year_released  runtime_in_min  \
# 0            Gladiator           2000             155
# 1              Memento           2000             113
# 2               Snatch           2000             104
# 3  Requiem for a Dream           2000             102
# 4                X-Men           2000             104
#
#                        genre   revenues  imdb_rating  user_votes  \
# 0   Action, Adventure, Drama  187705427          8.5     1295546
# 1          Mystery, Thriller   25544867          8.4     1088700
# 2              Comedy, Crime   30328156          8.3      760646
# 3                      Drama    3635482          8.3      742193
# 4  Action, Adventure, Sci-Fi  157299717          7.4      558716
#
#             director                                              actor
# 0       Ridley Scott  Russell Crowe, Joaquin Phoenix, Connie Nielsen...
# 1  Christopher Nolan  Guy Pearce, Carrie-Anne Moss, Joe Pantoliano, ...
# 2        Guy Ritchie  Jason Statham, Brad Pitt, Benicio Del Toro, De...
# 3   Darren Aronofsky  Ellen Burstyn, Jared Leto, Jennifer Connelly, ...
# 4       Bryan Singer  Patrick Stewart, Hugh Jackman, Ian McKellen, F...

# %%
df.isnull().sum()
# Out:
# movie_name         0
# year_released      0
# runtime_in_min     0
# genre              0
# revenues           0
# imdb_rating        0
# user_votes         0
# director          78
# actor             78
# dtype: int64

# %%
df.dropna(how='any', inplace=True)

# %%
df.shape
# Out:
# (816, 9)

# %% [markdown]
# ### 2) Creating a list from dataset (Question 1)

# %%
# Create new subset of dataset

rating_genre = df[['imdb_rating', 'genre']]

rating_genre.head(10)
# Out:
#    imdb_rating                        genre
# 0          8.5     Action, Adventure, Drama
# 1          8.4            Mystery, Thriller
# 2          8.3                Comedy, Crime
# 3          8.3                        Drama
# 4          7.4    Action, Adventure, Sci-Fi
# 5          7.8    Adventure, Drama, Romance
# 6          7.6         Comedy, Crime, Drama
# 7          7.3       Drama, Mystery, Sci-Fi
# 8          6.1  Action, Adventure, Thriller
# 9          7.0              Comedy, Romance

# %%
x = df['imdb_rating'].unique()  # imdb_rating in float format
len(x)

y = df['imdb_rating'].round(0).astype(int).unique() # imdb_rating in float format
len(y)

print('number of unique value in df[imdb_rating]:', len(x))     
print('number of unique value in rating_genre[imdb_rating]:', len(y))
# Out:
# number of unique value in df[imdb_rating]: 43
# number of unique value in rating_genre[imdb_rating]: 6

# %% [markdown]
# The above code shows that using imdb_rating in float format as number of transaction is preferred compared to as integer number
#
# Assuming that viewer preferences is based on user ratings, in this case imdb_rating

# %%
# Group by imdb_rating (43 unique ratings) and list all the genre in list format 

basket = rating_genre.groupby(['imdb_rating'])['genre'].apply(list)

print("\n", basket[:6])
# Out:
#  imdb_rating
# 4.1                           [Drama, Romance, Thriller]
# 4.7                          [Adventure, Drama, Fantasy]
# 4.9    [Action, Adventure, Comedy, Adventure, Drama, ...
# 5.0    [Drama, Mystery, Sci-Fi, Adventure, Drama, Fan...
# 5.2    [Action, Fantasy, Thriller, Drama, Fantasy, Ro...
# 5.3    [Comedy, Horror, Action, Crime, Action, Advent...
# 5.4                         [Action, Adventure, Fantasy]
# 5.5    [Action, Adventure, Comedy, Comedy, Mystery, S...
# 5.6    [Horror, Mystery, Action, Sci-Fi, Action, Adve...
# 5.7    [Comedy, Drama, Music, Action, Adventure, Sci-...
# 5.8    [Action, Horror, Sci-Fi, Action, Adventure, Fa...
# 5.9    [Action, Mystery, Sci-Fi, Action, Adventure, S...
# 6.0    [Action, Adventure, Sci-Fi, Action, Adventure,...
# Name: genre, dtype: object

# %%
# List all the genre in list format (for model preparation)

basket_list = list(basket)

print("\n", basket_list[:10])
# Out:
#  [['Drama, Romance, Thriller'], ['Adventure, Drama, Fantasy'], ['Action, Adventure, Comedy', 'Adventure, Drama, Fantasy'], ['Drama, Mystery, Sci-Fi', 'Adventure, Drama, Fantasy'], ['Action, Fantasy, Thriller', 'Drama, Fantasy, Romance', 'Action, Comedy, Fantasy', 'Action, Adventure, Sci-Fi'], ['Comedy, Horror', 'Action, Crime', 'Action, Adventure, Sci-Fi'], ['Action, Adventure, Fantasy'], ['Action, Adventure, Comedy', 'Comedy, Mystery, Sci-Fi', 'Action, Adventure, Fantasy', 'Comedy, Horror', 'Action, Adventure, Fantasy', 'Comedy', 'Action, Adventure, Sci-Fi', 'Adventure, Drama, Fantasy', 'Action, Comedy, Crime'], ['Horror, Mystery', 'Action, Sci-Fi', 'Action, Adventure, Horror', 'Action, Adventure, Family', 'Action, Adventure, Sci-Fi'], ['Comedy, Drama, Music', 'Action, Adventure, Sci-Fi', 'Action, Adventure, Family', 'Action, Adventure, Drama', 'Action, Adventure, Sci-Fi']]

# %% [markdown]
# ### 3) Convert list to dataframe with Boolean values

# %%
# Convert list to dataframe with boolean values

te = TransactionEncoder()
te_ary = te.fit(basket_list).transform(basket_list)

df2 = pd.DataFrame(te_ary, columns=te.columns_)
df2.head(10)
# Out:
#    Action, Adventure  Action, Adventure, Biography  Action, Adventure, Comedy  \
# 0              False                         False                      False
# 1              False                         False                      False
# 2              False                         False                       True
# 3              False                         False                      False
# 4              False                         False                      False
# 5              False                         False                      False
# 6              False                         False                      False
# 7              False                         False                       True
# 8              False                         False                      False
# 9              False                         False                      False
#
#    Action, Adventure, Crime  Action, Adventure, Drama  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
# 5                     False                     False
# 6                     False                     False
# 7                     False                     False
# 8                     False                     False
# 9                     False                      True
#
#    Action, Adventure, Family  Action, Adventure, Fantasy  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
# 5                      False                       False
# 6                      False                        True
# 7                      False                        True
# 8                       True                       False
# 9                       True                       False
#
#    Action, Adventure, History  Action, Adventure, Horror  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# 5                       False                      False
# 6                       False                      False
# 7                       False                      False
# 8                       False                       True
# 9                       False                      False
#
#    Action, Adventure, Mystery  ...  Horror  Horror, Mystery  \
# 0                       False  ...   False            False
# 1                       False  ...   False            False
# 2                       False  ...   False            False
# 3                       False  ...   False            False
# 4                       False  ...   False            False
# 5                       False  ...   False            False
# 6                       False  ...   False            False
# 7                       False  ...   False            False
# 8                       False  ...   False             True
# 9                       False  ...   False            False
#
#    Horror, Mystery, Thriller  Horror, Sci-Fi  Horror, Sci-Fi, Thriller  \
# 0                      False           False                     False
# 1                      False           False                     False
# 2                      False           False                     False
# 3                      False           False                     False
# 4                      False           False                     False
# 5                      False           False                     False
# 6                      False           False                     False
# 7                      False           False                     False
# 8                      False           False                     False
# 9                      False           False                     False
#
#    Horror, Thriller  Mystery, Sci-Fi, Thriller  Mystery, Thriller  \
# 0             False                      False              False
# 1             False                      False              False
# 2             False                      False              False
# 3             False                      False              False
# 4             False                      False              False
# 5             False                      False              False
# 6             False                      False              False
# 7             False                      False              False
# 8             False                      False              False
# 9             False                      False              False
#
#    Romance, Sci-Fi, Thriller  Sci-Fi, Thriller
# 0                      False             False
# 1                      False             False
# 2                      False             False
# 3                      False             False
# 4                      False             False
# 5                      False             False
# 6                      False             False
# 7                      False             False
# 8                      False             False
# 9                      False             False
#
# [10 rows x 157 columns]

# %% [markdown]
# The above table shows the distribution of each genre in one rating value (1 decimal rating number). False indicates no genre by the specific rating number whereas True indicates that the genre is rated for the specific rating.

# %% [markdown]
# ### 4) Find frequently occurring itemsets using Apriori Algorithm
#
# `Apriori` is an algorithm for frequent itemset mining and association rule learning over relational databases. Apriori is an algorithm for frequent itemset mining and Association Rule learning over relational databases. The algorithm identify the frequent individual items in the database and extending them to larger and larger itemsets as long as those itemsets appear sufficiently often in the database.
#
# The frequent itemsets determined by `Apriori` can be used to determine `Association Rules` which highlight general trends in the database. This has applications in domains such as market basket analysis.
#
# The `Support` and `Confidence` are measures to measure how interesting a rule is. These parameters are used to exclude rules in the result that have a `Support` or a `Confidence` lower than the minimum support and minimum confidence respectively. I have experimented a number trial of minimum support number and 0.2 is the best for this dataset.

# %% [markdown]
# 1)	Pros: Easy to code up
#
# 2)	Cons: May be slow on large datasets
#
# 3)	Works with: Numeric values, nominal values
#
#
# #### General approach to Apriori algorithm:
#
#     1)	Preparation: Any data type will work because we storing sets.
#     2)	Train: Use the Apriori algorithm to find frequent itemsets.
#     3)	Test: Doesn’t apply.
#     4)	Application: This will be used to find frequent itemsets and association rules between items.

# %%
# Frequently occurring itemsets using Apriori Algorithm

frequent_itemsets_apriori = apriori(df2, min_support=0.2, 
                                    use_colnames=True).sort_values(by='support', ascending=0)
frequent_itemsets_apriori
# Out:
#      support                                           itemsets
# 3   0.651163                        (Action, Adventure, Sci-Fi)
# 10  0.511628                     (Animation, Adventure, Comedy)
# 2   0.441860                       (Action, Adventure, Fantasy)
# 1   0.418605                         (Action, Adventure, Drama)
# 36  0.418605  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 26  0.395349  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 11  0.372093                                           (Comedy)
# 0   0.348837                        (Action, Adventure, Comedy)
# 23  0.348837  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 7   0.348837                          (Action, Crime, Thriller)
# 37  0.348837                (Action, Adventure, Sci-Fi, Comedy)
# 34  0.325581  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 29  0.325581  (Animation, Adventure, Comedy, Action, Adventu...
# 13  0.302326                           (Comedy, Drama, Romance)
# 43  0.302326  (Animation, Adventure, Comedy, Action, Crime, ...
# 62  0.302326  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 25  0.302326  (Animation, Adventure, Comedy, Action, Adventu...
# 46  0.302326             (Animation, Adventure, Comedy, Comedy)
# 19  0.302326  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 48  0.302326  (Comedy, Drama, Romance, Animation, Adventure,...
# 28  0.279070  (Action, Crime, Thriller, Action, Adventure, F...
# 71  0.279070  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 38  0.279070  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 68  0.279070  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 70  0.279070  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 65  0.255814  (Animation, Adventure, Comedy, Action, Crime, ...
# 63  0.255814  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 32  0.255814  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 60  0.255814  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 30  0.255814               (Action, Adventure, Fantasy, Comedy)
# ..       ...                                                ...
# 12  0.232558                                    (Comedy, Drama)
# 44  0.232558                  (Action, Crime, Thriller, Comedy)
# 14  0.232558                                  (Comedy, Romance)
# 69  0.232558  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 40  0.232558  (Action, Adventure, Thriller, Animation, Adven...
# 17  0.232558                                   (Drama, Romance)
# 18  0.232558  (Action, Adventure, Comedy, Action, Adventure,...
# 66  0.209302  (Animation, Adventure, Comedy, Action, Adventu...
# 77  0.209302  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 76  0.209302  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 64  0.209302  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 72  0.209302  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 73  0.209302  (Animation, Adventure, Comedy, Action, Crime, ...
# 39  0.209302       (Action, Adventure, Sci-Fi, Comedy, Romance)
# 59  0.209302  (Animation, Adventure, Comedy, Action, Adventu...
# 57  0.209302  (Animation, Adventure, Comedy, Action, Adventu...
# 51  0.209302              (Animation, Adventure, Comedy, Drama)
# 49  0.209302    (Animation, Adventure, Comedy, Comedy, Romance)
# 47  0.209302      (Comedy, Drama, Animation, Adventure, Comedy)
# 45  0.209302  (Animation, Adventure, Comedy, Adventure, Fami...
# 42  0.209302                    (Action, Comedy, Crime, Comedy)
# 41  0.209302  (Animation, Adventure, Comedy, Action, Comedy,...
# 35  0.209302  (Action, Adventure, Sci-Fi, Adventure, Family,...
# 33  0.209302  (Action, Adventure, Sci-Fi, Action, Comedy, Cr...
# 31  0.209302      (Action, Adventure, Fantasy, Comedy, Romance)
# 27  0.209302  (Action, Comedy, Crime, Action, Adventure, Fan...
# 24  0.209302  (Action, Adventure, Drama, Action, Crime, Thri...
# 16  0.209302                                            (Drama)
# 6   0.209302                             (Action, Crime, Drama)
# 78  0.209302  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
#
# [79 rows x 2 columns]

# %% [markdown]
# ### 5) Find frequently occurring itemsets using F-P Growth (Frequent Pattern Growth)
#
# 1) Pros: Usually faster than Apriori.
#
# 2) Cons: Difficult to implement; certain datasets degrade the performance.
#
# 3) Works with Nominal values.

# %% [markdown]
# #### General approach to FP-growth algorithm
#
#     1) Preparation: Discrete data is needed because we’re storing sets. For continuous data, it will need to be
#     quantized into discrete values.
#     2) Train: Build an FP-tree and mine the tree.
#     3) Test: Doesn’t apply.
#     4) Application: This can be used to identify commonly occurring items that can be used to make decisions,
#     suggest items, make forecasts, and so on.

# %% [markdown]
# The frequently occurring movie genre using F-P Growth as follows:

# %%
# frequently occurring itemsets using F-P Growth (Frequent Pattern Growth)

frequent_itemsets_fpgrowth = fpgrowth(df2, min_support=0.2, 
                                     use_colnames=True).sort_values(by='support', ascending=0)
frequent_itemsets_fpgrowth
# Out:
#      support                                           itemsets
# 2   0.651163                        (Action, Adventure, Sci-Fi)
# 11  0.511628                     (Animation, Adventure, Comedy)
# 3   0.441860                       (Action, Adventure, Fantasy)
# 67  0.418605  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 6   0.418605                         (Action, Adventure, Drama)
# 26  0.395349  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 4   0.372093                                           (Comedy)
# 40  0.348837  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 1   0.348837                        (Action, Adventure, Comedy)
# 8   0.348837                          (Action, Crime, Thriller)
# 29  0.348837                (Action, Adventure, Sci-Fi, Comedy)
# 27  0.325581  (Animation, Adventure, Comedy, Action, Adventu...
# 50  0.325581  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 13  0.302326                           (Comedy, Drama, Romance)
# 28  0.302326  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 68  0.302326  (Comedy, Drama, Romance, Animation, Adventure,...
# 54  0.302326  (Animation, Adventure, Comedy, Action, Crime, ...
# 18  0.302326  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 31  0.302326             (Animation, Adventure, Comedy, Comedy)
# 42  0.302326  (Animation, Adventure, Comedy, Action, Adventu...
# 69  0.279070  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 61  0.279070  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 52  0.279070  (Action, Crime, Thriller, Action, Adventure, F...
# 71  0.279070  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 35  0.279070  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 30  0.255814               (Action, Adventure, Fantasy, Comedy)
# 32  0.255814  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 45  0.255814  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 21  0.255814  (Animation, Adventure, Comedy, Action, Adventu...
# 19  0.255814                (Action, Adventure, Comedy, Comedy)
# ..       ...                                                ...
# 16  0.232558                                   (Drama, Romance)
# 76  0.232558  (Crime, Drama, Thriller, Animation, Adventure,...
# 20  0.232558  (Action, Adventure, Comedy, Action, Adventure,...
# 22  0.232558  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 24  0.232558  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 25  0.232558  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 60  0.232558  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 75  0.209302      (Comedy, Drama, Animation, Adventure, Comedy)
# 65  0.209302  (Action, Adventure, Sci-Fi, Adventure, Family,...
# 66  0.209302  (Animation, Adventure, Comedy, Adventure, Fami...
# 74  0.209302  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 73  0.209302  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 39  0.209302  (Animation, Adventure, Comedy, Action, Comedy,...
# 57  0.209302  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 37  0.209302  (Action, Comedy, Crime, Action, Adventure, Fan...
# 12  0.209302                             (Action, Crime, Drama)
# 17  0.209302                                            (Drama)
# 23  0.209302  (Animation, Adventure, Comedy, Action, Adventu...
# 33  0.209302  (Animation, Adventure, Comedy, Action, Adventu...
# 34  0.209302  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 36  0.209302                    (Action, Comedy, Crime, Comedy)
# 38  0.209302  (Action, Adventure, Sci-Fi, Action, Comedy, Cr...
# 56  0.209302  (Animation, Adventure, Comedy, Action, Crime, ...
# 44  0.209302  (Animation, Adventure, Comedy, Action, Adventu...
# 46  0.209302      (Action, Adventure, Fantasy, Comedy, Romance)
# 47  0.209302       (Action, Adventure, Sci-Fi, Comedy, Romance)
# 48  0.209302    (Animation, Adventure, Comedy, Comedy, Romance)
# 49  0.209302  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 53  0.209302  (Action, Adventure, Drama, Action, Crime, Thri...
# 78  0.209302              (Animation, Adventure, Comedy, Drama)
#
# [79 rows x 2 columns]

# %% [markdown]
# ### 6) Mine the Association Rules
#
# Association rules analysis is a technique to uncover how items are associated to each other. There are 3 common ways to measure association:
#
# 1) Measure 1: `Support`. This says how popular an itemset is, as measured by the proportion of transactions in which an itemset appears. If we discover that genre of certain movie beyond a certain proportion, we might consider using that proportion as our support threshold. Thus, we identify itemsets with `Support` values above this threshold as significant itemsets.
#
# 2) Measure 2: `Confidence`. This says how likely genre B is chosen when genre A is chosen, expressed as {A -> B}. This is measured by the proportion of transactions with genre A, in which genre B also appears. One drawback of the `Confidence` measure is that it might misrepresent the importance of an association. This is because it only accounts for how popular A are, but not B. If B are also very popular in general, there will be a higher chance that a transaction containing A will also contain B, thus inflating the confidence measure. To account for the base popularity of both constituent items, we use a third measure called `Lift`.
#
# 3) Measure 3: `Lift`. This says how likely genre B is chosen when genre A is chosen, while controlling for how popular item B is.
#
#     a)Lift of {A -> B} = 1, means no association between items.
#     b)Lift {A -> B} > 1, means that item B is likely to be bought if item A is bought,
#     c)Lift {A -> B} < 1, means that item B is unlikely to be bought if item A is bought.

# %% [markdown]
# Now I want to build our association rules. Apyori's apriori function accepts a number of arguments, mainly:
#
#     a)transaction: list of list of items in transactions (eg. [['A', 'B'], ['B', 'C']]).
#     b)min_support: Minimum support of relations in float percentage. Im using 0.2
#     c)min_confidence: Minimum confidence of relations in float percentage. Default 0.0.
#     d)min_lift: Minimum lift of relations in float percentage. Default 0.0.
#     e)max_length: Max length of the relations. Default None.

# %% [markdown]
# #### 6a) Mine the Association Rules using Apriori Algorithm

# %%
# Generate the Association Rules using Apriori Algorithm with their corresponding support, confidence and lift. 

rules_apriori = association_rules(frequent_itemsets_apriori, metric="lift", min_threshold=1)
rules_apriori = rules_apriori.sort_values(by='lift', ascending=0)

# %%
# View top 10 rules 

rules_apriori.head()
# Out:
#                                            antecedents  \
# 86              (Animation, Adventure, Comedy, Comedy)
# 87                            (Comedy, Drama, Romance)
# 251                           (Comedy, Drama, Romance)
# 249             (Animation, Adventure, Comedy, Comedy)
# 244  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
#
#                                            consequents  antecedent support  \
# 86                            (Comedy, Drama, Romance)            0.302326
# 87              (Animation, Adventure, Comedy, Comedy)            0.302326
# 251  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.302326
# 249  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...            0.302326
# 244             (Animation, Adventure, Comedy, Comedy)            0.279070
#
#      consequent support   support  confidence      lift  leverage  conviction
# 86             0.302326  0.232558    0.769231  2.544379  0.141157    3.023256
# 87             0.302326  0.232558    0.769231  2.544379  0.141157    3.023256
# 251            0.279070  0.209302    0.692308  2.480769  0.124932    2.343023
# 249            0.279070  0.209302    0.692308  2.480769  0.124932    2.343023
# 244            0.302326  0.209302    0.750000  2.480769  0.124932    2.790698

# %% [markdown]
# `Antecedent` and a `Consequent`, both of which are a list of genres. Note that implication here is co-occurrence and not causality.

# %% [markdown]
# The maximum value of `Lift` is `2.5` and maximum value for `Confidence` is `1.0` found in `Association Rules using Apriori Algorithm`. I want to view for a large value of `Lift` and `Confidence` with range value of more than 1 and more than 0.8 respectively. This means that genre B is likely to be chosen if genre A is chosen

# %%
# Filter the dataframe for Lift > 1 and high confidence > 0.8

rules_apriori[(rules_apriori['lift'] > 1) & 
              (rules_apriori['confidence'] > 0.8)].sort_values(by='lift', ascending=0)
# Out:
#                                            antecedents  \
# 191                                  (Comedy, Romance)
# 187       (Action, Adventure, Sci-Fi, Comedy, Romance)
# 34                            (Comedy, Drama, Romance)
# 212  (Action, Adventure, Comedy, Animation, Adventu...
# 226                            (Action, Comedy, Crime)
# 94                       (Action, Adventure, Thriller)
# 248                   (Comedy, Drama, Romance, Comedy)
# 167                  (Action, Crime, Thriller, Comedy)
# 235                                  (Comedy, Romance)
# 135  (Action, Crime, Thriller, Action, Adventure, F...
# 181               (Action, Adventure, Fantasy, Comedy)
# 30   (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 85                    (Comedy, Drama, Romance, Comedy)
# 123                                   (Drama, Romance)
# 26                            (Comedy, Drama, Romance)
# 241  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 219                                            (Drama)
# 50   (Animation, Adventure, Comedy, Action, Crime, ...
# 126  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 236                            (Action, Comedy, Crime)
# 52   (Action, Crime, Thriller, Action, Adventure, F...
# 124                           (Crime, Drama, Thriller)
# 148                      (Action, Adventure, Thriller)
# 128  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 90   (Action, Adventure, Sci-Fi, Action, Adventure,...
# 225                       (Adventure, Family, Fantasy)
# 160  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 221                                  (Comedy, Romance)
# 222                                    (Comedy, Drama)
# 200                  (Action, Crime, Thriller, Comedy)
# ..                                                 ...
# 188      (Action, Adventure, Fantasy, Comedy, Romance)
# 63                       (Action, Adventure, Thriller)
# 58                (Action, Adventure, Fantasy, Comedy)
# 92   (Action, Adventure, Thriller, Animation, Adven...
# 175  (Animation, Adventure, Comedy, Action, Adventu...
# 144                  (Action, Crime, Thriller, Comedy)
# 161  (Animation, Adventure, Comedy, Action, Crime, ...
# 116  (Action, Adventure, Comedy, Action, Adventure,...
# 7                                             (Comedy)
# 9                            (Action, Crime, Thriller)
# 16   (Animation, Adventure, Comedy, Action, Adventu...
# 40   (Animation, Adventure, Comedy, Action, Crime, ...
# 32   (Comedy, Drama, Romance, Animation, Adventure,...
# 37                            (Comedy, Drama, Romance)
# 46              (Animation, Adventure, Comedy, Comedy)
# 74   (Action, Crime, Thriller, Action, Adventure, F...
# 104                (Action, Adventure, Comedy, Comedy)
# 110  (Action, Adventure, Comedy, Animation, Adventu...
# 98   (Action, Adventure, Drama, Action, Adventure, ...
# 129  (Animation, Adventure, Comedy, Action, Crime, ...
# 231                       (Adventure, Family, Fantasy)
# 194                   (Comedy, Drama, Romance, Comedy)
# 205                                  (Comedy, Romance)
# 243  (Comedy, Drama, Romance, Animation, Adventure,...
# 3                         (Action, Adventure, Fantasy)
# 25                         (Action, Adventure, Comedy)
# 66   (Animation, Adventure, Comedy, Action, Adventu...
# 5                           (Action, Adventure, Drama)
# 233                            (Action, Comedy, Crime)
# 1                       (Animation, Adventure, Comedy)
#
#                                            consequents  antecedent support  \
# 191  (Action, Adventure, Sci-Fi, Action, Adventure,...            0.232558
# 187                       (Action, Adventure, Fantasy)            0.209302
# 34   (Action, Adventure, Sci-Fi, Animation, Adventu...            0.302326
# 212                                           (Comedy)            0.255814
# 226                                           (Comedy)            0.255814
# 94   (Action, Adventure, Sci-Fi, Animation, Adventu...            0.255814
# 248  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.232558
# 167  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.232558
# 235                       (Action, Adventure, Fantasy)            0.232558
# 135  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.279070
# 181  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.255814
# 30                      (Animation, Adventure, Comedy)            0.279070
# 85                      (Animation, Adventure, Comedy)            0.232558
# 123                     (Animation, Adventure, Comedy)            0.232558
# 26                      (Animation, Adventure, Comedy)            0.302326
# 241                     (Animation, Adventure, Comedy)            0.209302
# 219                     (Animation, Adventure, Comedy)            0.209302
# 50                        (Action, Adventure, Fantasy)            0.302326
# 126                       (Action, Adventure, Fantasy)            0.279070
# 236                       (Action, Adventure, Fantasy)            0.255814
# 52                      (Animation, Adventure, Comedy)            0.279070
# 124                     (Animation, Adventure, Comedy)            0.255814
# 148                     (Animation, Adventure, Comedy)            0.255814
# 128                     (Animation, Adventure, Comedy)            0.255814
# 90                      (Animation, Adventure, Comedy)            0.255814
# 225                     (Animation, Adventure, Comedy)            0.232558
# 160                     (Animation, Adventure, Comedy)            0.232558
# 221                     (Animation, Adventure, Comedy)            0.232558
# 222                     (Animation, Adventure, Comedy)            0.232558
# 200                     (Animation, Adventure, Comedy)            0.232558
# ..                                                 ...                 ...
# 188                        (Action, Adventure, Sci-Fi)            0.209302
# 63                         (Action, Adventure, Sci-Fi)            0.255814
# 58                         (Action, Adventure, Sci-Fi)            0.255814
# 92                         (Action, Adventure, Sci-Fi)            0.232558
# 175                        (Action, Adventure, Sci-Fi)            0.209302
# 144                        (Action, Adventure, Sci-Fi)            0.232558
# 161                        (Action, Adventure, Sci-Fi)            0.209302
# 116                        (Action, Adventure, Sci-Fi)            0.232558
# 7                          (Action, Adventure, Sci-Fi)            0.372093
# 9                          (Action, Adventure, Sci-Fi)            0.348837
# 16                         (Action, Adventure, Sci-Fi)            0.325581
# 40                         (Action, Adventure, Sci-Fi)            0.302326
# 32                         (Action, Adventure, Sci-Fi)            0.302326
# 37                         (Action, Adventure, Sci-Fi)            0.302326
# 46                         (Action, Adventure, Sci-Fi)            0.302326
# 74                         (Action, Adventure, Sci-Fi)            0.279070
# 104                        (Action, Adventure, Sci-Fi)            0.255814
# 110                        (Action, Adventure, Sci-Fi)            0.255814
# 98                         (Action, Adventure, Sci-Fi)            0.255814
# 129                        (Action, Adventure, Sci-Fi)            0.255814
# 231                        (Action, Adventure, Sci-Fi)            0.232558
# 194                        (Action, Adventure, Sci-Fi)            0.232558
# 205                        (Action, Adventure, Sci-Fi)            0.232558
# 243                        (Action, Adventure, Sci-Fi)            0.232558
# 3                          (Action, Adventure, Sci-Fi)            0.441860
# 25                         (Action, Adventure, Sci-Fi)            0.348837
# 66                         (Action, Adventure, Sci-Fi)            0.302326
# 5                          (Action, Adventure, Sci-Fi)            0.418605
# 233                        (Action, Adventure, Sci-Fi)            0.255814
# 1                          (Action, Adventure, Sci-Fi)            0.511628
#
#      consequent support   support  confidence      lift  leverage  conviction
# 191            0.395349  0.209302    0.900000  2.276471  0.117361    6.046512
# 187            0.441860  0.209302    1.000000  2.263158  0.116820         inf
# 34             0.418605  0.279070    0.923077  2.205128  0.152515    7.558140
# 212            0.372093  0.209302    0.818182  2.198864  0.114116    3.453488
# 226            0.372093  0.209302    0.818182  2.198864  0.114116    3.453488
# 94             0.418605  0.232558    0.909091  2.171717  0.125473    6.395349
# 248            0.418605  0.209302    0.900000  2.150000  0.111952    5.813953
# 167            0.418605  0.209302    0.900000  2.150000  0.111952    5.813953
# 235            0.441860  0.209302    0.900000  2.036842  0.106544    5.581395
# 135            0.418605  0.232558    0.833333  1.990741  0.115738    3.488372
# 181            0.418605  0.209302    0.818182  1.954545  0.102217    3.197674
# 30             0.511628  0.279070    1.000000  1.954545  0.136290         inf
# 85             0.511628  0.232558    1.000000  1.954545  0.113575         inf
# 123            0.511628  0.232558    1.000000  1.954545  0.113575         inf
# 26             0.511628  0.302326    1.000000  1.954545  0.147647         inf
# 241            0.511628  0.209302    1.000000  1.954545  0.102217         inf
# 219            0.511628  0.209302    1.000000  1.954545  0.102217         inf
# 50             0.441860  0.255814    0.846154  1.914980  0.122228    3.627907
# 126            0.441860  0.232558    0.833333  1.885965  0.109248    3.348837
# 236            0.441860  0.209302    0.818182  1.851675  0.096268    3.069767
# 52             0.511628  0.255814    0.916667  1.791667  0.113034    5.860465
# 124            0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 148            0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 128            0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 90             0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 225            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 160            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 221            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 222            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 200            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# ..                  ...       ...         ...       ...       ...         ...
# 188            0.651163  0.209302    1.000000  1.535714  0.073012         inf
# 63             0.651163  0.255814    1.000000  1.535714  0.089237         inf
# 58             0.651163  0.255814    1.000000  1.535714  0.089237         inf
# 92             0.651163  0.232558    1.000000  1.535714  0.081125         inf
# 175            0.651163  0.209302    1.000000  1.535714  0.073012         inf
# 144            0.651163  0.232558    1.000000  1.535714  0.081125         inf
# 161            0.651163  0.209302    1.000000  1.535714  0.073012         inf
# 116            0.651163  0.232558    1.000000  1.535714  0.081125         inf
# 7              0.651163  0.348837    0.937500  1.439732  0.106544    5.581395
# 9              0.651163  0.325581    0.933333  1.433333  0.098432    5.232558
# 16             0.651163  0.302326    0.928571  1.426020  0.090319    4.883721
# 40             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 32             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 37             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 46             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 74             0.651163  0.255814    0.916667  1.407738  0.074094    4.186047
# 104            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 110            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 98             0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 129            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 231            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 194            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 205            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 243            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 3              0.651163  0.395349    0.894737  1.374060  0.107626    3.313953
# 25             0.651163  0.302326    0.866667  1.330952  0.075176    2.616279
# 66             0.651163  0.255814    0.846154  1.299451  0.058951    2.267442
# 5              0.651163  0.348837    0.833333  1.279762  0.076257    2.093023
# 233            0.651163  0.209302    0.818182  1.256494  0.042726    1.918605
# 1              0.651163  0.418605    0.818182  1.256494  0.085452    1.918605
#
# [68 rows x 9 columns]

# %% [markdown]
# #### Findings 1:
#
# 1) About 68 rules have a high `Lift` value (more than 1), which means that it increase the chances of occurence of genre in `Consequents` in spite high `Confidence` value
#
# 2) A value of `Lift` which greater than 1 indicate for high association between `Antecedents` and `Consequents`. The greater the value of `Lift`, the greater are the chances of preference to choose genre in `Consequents`. Here, if the viewer has already watched movie with genre of (Action, Adventure, Sci-Fi, Comedy, Romance), viewer will likely watch (Action, Adventure, Fantasy) movie genre.
#
# 3) Lift is the measure that will help movie producer to decide what kind of movie genre to produce next based on viewer's rating or acceptance.
#
# 4) These 68 rules also have high `Confidence` number, range between 0.8 to 1.0.

# %% [markdown]
# #### 6b) Mine the Association Rules using F-P Growth

# %%
rules_fpgrowth = association_rules(frequent_itemsets_fpgrowth, metric="lift", min_threshold=1)
rules_fpgrowth = rules_fpgrowth.sort_values(by='lift', ascending=0)

# %%
rules_fpgrowth.head()
# Out:
#                                            antecedents  \
# 110             (Animation, Adventure, Comedy, Comedy)
# 111                           (Comedy, Drama, Romance)
# 167             (Animation, Adventure, Comedy, Comedy)
# 169                           (Comedy, Drama, Romance)
# 162  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
#
#                                            consequents  antecedent support  \
# 110                           (Comedy, Drama, Romance)            0.302326
# 111             (Animation, Adventure, Comedy, Comedy)            0.302326
# 167  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...            0.302326
# 169  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.302326
# 162             (Animation, Adventure, Comedy, Comedy)            0.279070
#
#      consequent support   support  confidence      lift  leverage  conviction
# 110            0.302326  0.232558    0.769231  2.544379  0.141157    3.023256
# 111            0.302326  0.232558    0.769231  2.544379  0.141157    3.023256
# 167            0.279070  0.209302    0.692308  2.480769  0.124932    2.343023
# 169            0.279070  0.209302    0.692308  2.480769  0.124932    2.343023
# 162            0.302326  0.209302    0.750000  2.480769  0.124932    2.790698

# %% [markdown]
# The maximum value of `Lift` is `2.5` and maximum value for `Confidence` is `1.0` found in `Association Rules using F-P Growth Algorithm` same like the `Apriori Algorithm`. I want to view for a large value of `Lift` and `Confidence` with range value of more than 1  and more than 0.8 respectively

# %%
# Filter the dataframe for Lift > 1 and high confidence > 0.8

rules_fpgrowth[(rules_fpgrowth['lift'] > 1) & 
               (rules_fpgrowth['confidence'] > 0.8)].sort_values(by='lift', ascending=0)
# Out:
#                                            antecedents  \
# 249                                  (Comedy, Romance)
# 245       (Action, Adventure, Sci-Fi, Comedy, Romance)
# 42                            (Comedy, Drama, Romance)
# 196  (Action, Adventure, Comedy, Animation, Adventu...
# 222                            (Action, Comedy, Crime)
# 90                       (Action, Adventure, Thriller)
# 166                   (Comedy, Drama, Romance, Comedy)
# 189                  (Action, Crime, Thriller, Comedy)
# 239                                  (Comedy, Romance)
# 147  (Action, Crime, Thriller, Action, Adventure, F...
# 217               (Action, Adventure, Fantasy, Comedy)
# 159  (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 38   (Action, Adventure, Sci-Fi, Comedy, Drama, Rom...
# 109                   (Comedy, Drama, Romance, Comedy)
# 253                                            (Drama)
# 18                            (Comedy, Drama, Romance)
# 115                                   (Drama, Romance)
# 76   (Animation, Adventure, Comedy, Action, Crime, ...
# 138  (Action, Adventure, Sci-Fi, Animation, Adventu...
# 194                            (Action, Comedy, Crime)
# 78   (Action, Crime, Thriller, Action, Adventure, F...
# 116                           (Crime, Drama, Thriller)
# 140  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 86   (Action, Adventure, Sci-Fi, Action, Adventure,...
# 98                       (Action, Adventure, Thriller)
# 228                  (Action, Crime, Thriller, Comedy)
# 157                       (Adventure, Family, Fantasy)
# 152                                    (Comedy, Drama)
# 182  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 243                                  (Comedy, Romance)
# ..                                                 ...
# 183  (Animation, Adventure, Comedy, Action, Crime, ...
# 54                (Action, Adventure, Fantasy, Comedy)
# 211  (Animation, Adventure, Comedy, Action, Adventu...
# 69                       (Action, Adventure, Thriller)
# 246      (Action, Adventure, Fantasy, Comedy, Romance)
# 128  (Action, Adventure, Comedy, Action, Adventure,...
# 88   (Action, Adventure, Thriller, Animation, Adven...
# 94                   (Action, Crime, Thriller, Comedy)
# 7                                             (Comedy)
# 11                           (Action, Crime, Thriller)
# 14   (Animation, Adventure, Comedy, Action, Adventu...
# 46              (Animation, Adventure, Comedy, Comedy)
# 40   (Comedy, Drama, Romance, Animation, Adventure,...
# 32   (Animation, Adventure, Comedy, Action, Crime, ...
# 29                            (Comedy, Drama, Romance)
# 72   (Action, Crime, Thriller, Action, Adventure, F...
# 141  (Animation, Adventure, Comedy, Action, Crime, ...
# 134  (Action, Adventure, Comedy, Animation, Adventu...
# 122                (Action, Adventure, Comedy, Comedy)
# 102  (Action, Adventure, Drama, Action, Adventure, ...
# 174                   (Comedy, Drama, Romance, Comedy)
# 155                       (Adventure, Family, Fantasy)
# 161  (Comedy, Drama, Romance, Animation, Adventure,...
# 241                                  (Comedy, Romance)
# 3                         (Action, Adventure, Fantasy)
# 23                         (Action, Adventure, Comedy)
# 60   (Animation, Adventure, Comedy, Action, Adventu...
# 5                           (Action, Adventure, Drama)
# 225                            (Action, Comedy, Crime)
# 1                       (Animation, Adventure, Comedy)
#
#                                            consequents  antecedent support  \
# 249  (Action, Adventure, Sci-Fi, Action, Adventure,...            0.232558
# 245                       (Action, Adventure, Fantasy)            0.209302
# 42   (Action, Adventure, Sci-Fi, Animation, Adventu...            0.302326
# 196                                           (Comedy)            0.255814
# 222                                           (Comedy)            0.255814
# 90   (Action, Adventure, Sci-Fi, Animation, Adventu...            0.255814
# 166  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.232558
# 189  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.232558
# 239                       (Action, Adventure, Fantasy)            0.232558
# 147  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.279070
# 217  (Action, Adventure, Sci-Fi, Animation, Adventu...            0.255814
# 159                     (Animation, Adventure, Comedy)            0.209302
# 38                      (Animation, Adventure, Comedy)            0.279070
# 109                     (Animation, Adventure, Comedy)            0.232558
# 253                     (Animation, Adventure, Comedy)            0.209302
# 18                      (Animation, Adventure, Comedy)            0.302326
# 115                     (Animation, Adventure, Comedy)            0.232558
# 76                        (Action, Adventure, Fantasy)            0.302326
# 138                       (Action, Adventure, Fantasy)            0.279070
# 194                       (Action, Adventure, Fantasy)            0.255814
# 78                      (Animation, Adventure, Comedy)            0.279070
# 116                     (Animation, Adventure, Comedy)            0.255814
# 140                     (Animation, Adventure, Comedy)            0.255814
# 86                      (Animation, Adventure, Comedy)            0.255814
# 98                      (Animation, Adventure, Comedy)            0.255814
# 228                     (Animation, Adventure, Comedy)            0.232558
# 157                     (Animation, Adventure, Comedy)            0.232558
# 152                     (Animation, Adventure, Comedy)            0.232558
# 182                     (Animation, Adventure, Comedy)            0.232558
# 243                     (Animation, Adventure, Comedy)            0.232558
# ..                                                 ...                 ...
# 183                        (Action, Adventure, Sci-Fi)            0.209302
# 54                         (Action, Adventure, Sci-Fi)            0.255814
# 211                        (Action, Adventure, Sci-Fi)            0.209302
# 69                         (Action, Adventure, Sci-Fi)            0.255814
# 246                        (Action, Adventure, Sci-Fi)            0.209302
# 128                        (Action, Adventure, Sci-Fi)            0.232558
# 88                         (Action, Adventure, Sci-Fi)            0.232558
# 94                         (Action, Adventure, Sci-Fi)            0.232558
# 7                          (Action, Adventure, Sci-Fi)            0.372093
# 11                         (Action, Adventure, Sci-Fi)            0.348837
# 14                         (Action, Adventure, Sci-Fi)            0.325581
# 46                         (Action, Adventure, Sci-Fi)            0.302326
# 40                         (Action, Adventure, Sci-Fi)            0.302326
# 32                         (Action, Adventure, Sci-Fi)            0.302326
# 29                         (Action, Adventure, Sci-Fi)            0.302326
# 72                         (Action, Adventure, Sci-Fi)            0.279070
# 141                        (Action, Adventure, Sci-Fi)            0.255814
# 134                        (Action, Adventure, Sci-Fi)            0.255814
# 122                        (Action, Adventure, Sci-Fi)            0.255814
# 102                        (Action, Adventure, Sci-Fi)            0.255814
# 174                        (Action, Adventure, Sci-Fi)            0.232558
# 155                        (Action, Adventure, Sci-Fi)            0.232558
# 161                        (Action, Adventure, Sci-Fi)            0.232558
# 241                        (Action, Adventure, Sci-Fi)            0.232558
# 3                          (Action, Adventure, Sci-Fi)            0.441860
# 23                         (Action, Adventure, Sci-Fi)            0.348837
# 60                         (Action, Adventure, Sci-Fi)            0.302326
# 5                          (Action, Adventure, Sci-Fi)            0.418605
# 225                        (Action, Adventure, Sci-Fi)            0.255814
# 1                          (Action, Adventure, Sci-Fi)            0.511628
#
#      consequent support   support  confidence      lift  leverage  conviction
# 249            0.395349  0.209302    0.900000  2.276471  0.117361    6.046512
# 245            0.441860  0.209302    1.000000  2.263158  0.116820         inf
# 42             0.418605  0.279070    0.923077  2.205128  0.152515    7.558140
# 196            0.372093  0.209302    0.818182  2.198864  0.114116    3.453488
# 222            0.372093  0.209302    0.818182  2.198864  0.114116    3.453488
# 90             0.418605  0.232558    0.909091  2.171717  0.125473    6.395349
# 166            0.418605  0.209302    0.900000  2.150000  0.111952    5.813953
# 189            0.418605  0.209302    0.900000  2.150000  0.111952    5.813953
# 239            0.441860  0.209302    0.900000  2.036842  0.106544    5.581395
# 147            0.418605  0.232558    0.833333  1.990741  0.115738    3.488372
# 217            0.418605  0.209302    0.818182  1.954545  0.102217    3.197674
# 159            0.511628  0.209302    1.000000  1.954545  0.102217         inf
# 38             0.511628  0.279070    1.000000  1.954545  0.136290         inf
# 109            0.511628  0.232558    1.000000  1.954545  0.113575         inf
# 253            0.511628  0.209302    1.000000  1.954545  0.102217         inf
# 18             0.511628  0.302326    1.000000  1.954545  0.147647         inf
# 115            0.511628  0.232558    1.000000  1.954545  0.113575         inf
# 76             0.441860  0.255814    0.846154  1.914980  0.122228    3.627907
# 138            0.441860  0.232558    0.833333  1.885965  0.109248    3.348837
# 194            0.441860  0.209302    0.818182  1.851675  0.096268    3.069767
# 78             0.511628  0.255814    0.916667  1.791667  0.113034    5.860465
# 116            0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 140            0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 86             0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 98             0.511628  0.232558    0.909091  1.776860  0.101677    5.372093
# 228            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 157            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 152            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 182            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# 243            0.511628  0.209302    0.900000  1.759091  0.090319    4.883721
# ..                  ...       ...         ...       ...       ...         ...
# 183            0.651163  0.209302    1.000000  1.535714  0.073012         inf
# 54             0.651163  0.255814    1.000000  1.535714  0.089237         inf
# 211            0.651163  0.209302    1.000000  1.535714  0.073012         inf
# 69             0.651163  0.255814    1.000000  1.535714  0.089237         inf
# 246            0.651163  0.209302    1.000000  1.535714  0.073012         inf
# 128            0.651163  0.232558    1.000000  1.535714  0.081125         inf
# 88             0.651163  0.232558    1.000000  1.535714  0.081125         inf
# 94             0.651163  0.232558    1.000000  1.535714  0.081125         inf
# 7              0.651163  0.348837    0.937500  1.439732  0.106544    5.581395
# 11             0.651163  0.325581    0.933333  1.433333  0.098432    5.232558
# 14             0.651163  0.302326    0.928571  1.426020  0.090319    4.883721
# 46             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 40             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 32             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 29             0.651163  0.279070    0.923077  1.417582  0.082207    4.534884
# 72             0.651163  0.255814    0.916667  1.407738  0.074094    4.186047
# 141            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 134            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 122            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 102            0.651163  0.232558    0.909091  1.396104  0.065982    3.837209
# 174            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 155            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 161            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 241            0.651163  0.209302    0.900000  1.382143  0.057869    3.488372
# 3              0.651163  0.395349    0.894737  1.374060  0.107626    3.313953
# 23             0.651163  0.302326    0.866667  1.330952  0.075176    2.616279
# 60             0.651163  0.255814    0.846154  1.299451  0.058951    2.267442
# 5              0.651163  0.348837    0.833333  1.279762  0.076257    2.093023
# 225            0.651163  0.209302    0.818182  1.256494  0.042726    1.918605
# 1              0.651163  0.418605    0.818182  1.256494  0.085452    1.918605
#
# [68 rows x 9 columns]

# %% [markdown]
# #### Findings 2:
#
# 1) The output from `F-P Growth algorithm` is same like `Apriori algorithm` for this case study. About 68 rule have a high `Lift` value (more than 1), which means that it occurs more frequently than would be expected given the number of transaction
#
# 2) These 68 rules of high `Lift` value also have high `Confidence` number, range between 0.8 to 1.0.
#
# 3) `F-P Growth algorithm` showed faster in processing the data than `Apriori algorithm`

# %%
rules_apriori.to_csv('Apriori_Ratings_Genre.csv',mode = 'w', index=False, header=True)

# %%
rules_fpgrowth.to_csv('FPGrowth_Ratings_Genre.csv',mode = 'w', index=False, header=True)
