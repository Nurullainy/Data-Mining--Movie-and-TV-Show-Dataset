# %% [markdown]
# ## Final Exam WQD 7005 Data Mining
# ## Question 4
#
# ### Name: Nurullainy binti Mat Rashid
# ### ID :  17036591

# %% [markdown]
# ### Topic: Rule Mining  of Internet Movie Database (IMDb)
#
# The objectives are to find frequent itemsets and mining Associatio Rules using data from IMDb. The data was collected from the following website : https://www.imdb.com/search/title/?year=2017

# %% [markdown]
# In order to achieve the task, I will be going to cover the following steps:
#
#     1) Importing required libraries
#     2) Creating a list from dataset (Question 1)
#     3) Convert list to dataframe with boolean values
#     4) Find frequently occurring itemsets using Apriori Algorithm
#     5) Find frequently occurring itemsets using F-P Growth
#     6) Mine the Association Rules

# %% [markdown]
# ### 1) Importing required libraries

# %%
import pandas as pd
import numpy as np

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

import csv

# %%
# Load dataset

df = pd.read_csv('movies_imdb_preprocessed.csv')
df.head()
# Out:
#             movie_name  year_released  runtime_in_min  \
# 0            Gladiator           2000             155
# 1              Memento           2000             113
# 2               Snatch           2000             104
# 3  Requiem for a Dream           2000             102
# 4                X-Men           2000             104
#
#                        genre   revenues  imdb_rating  user_votes  \
# 0   Action, Adventure, Drama  187705427          8.5     1295546
# 1          Mystery, Thriller   25544867          8.4     1088700
# 2              Comedy, Crime   30328156          8.3      760646
# 3                      Drama    3635482          8.3      742193
# 4  Action, Adventure, Sci-Fi  157299717          7.4      558716
#
#             director                                              actor
# 0       Ridley Scott  Russell Crowe, Joaquin Phoenix, Connie Nielsen...
# 1  Christopher Nolan  Guy Pearce, Carrie-Anne Moss, Joe Pantoliano, ...
# 2        Guy Ritchie  Jason Statham, Brad Pitt, Benicio Del Toro, De...
# 3   Darren Aronofsky  Ellen Burstyn, Jared Leto, Jennifer Connelly, ...
# 4       Bryan Singer  Patrick Stewart, Hugh Jackman, Ian McKellen, F...

# %%
df.isnull().sum()
# Out:
# movie_name         0
# year_released      0
# runtime_in_min     0
# genre              0
# revenues           0
# imdb_rating        0
# user_votes         0
# director          78
# actor             78
# dtype: int64

# %%
df.dropna(how='any', inplace=True)

# %%
df.shape
# Out:
# (816, 9)

# %% [markdown]
# ### 2) Creating a list from dataset (Question 1)

# %%
# Create new subset of dataset

revenue_actor = df[['revenues', 'genre']]

revenue_actor.head(10)
# Out:
#     revenues                        genre
# 0  187705427     Action, Adventure, Drama
# 1   25544867            Mystery, Thriller
# 2   30328156                Comedy, Crime
# 3    3635482                        Drama
# 4  157299717    Action, Adventure, Sci-Fi
# 5  233632142    Adventure, Drama, Romance
# 6   15070285         Comedy, Crime, Drama
# 7   95011339       Drama, Mystery, Sci-Fi
# 8  215409889  Action, Adventure, Thriller
# 9  166244045              Comedy, Romance

# %%
# Change format of revenues data

df1 = revenue_actor['revenues'].div(1000000).to_frame('col') # Change to Million notation
df1.shape

revenue_actor['revenues'] = df1['col']
revenue_actor.info()


revenue_actor['revenues'] = revenue_actor['revenues'].round(0).astype(int)
revenue_actor.columns = ['revenues in mil', 'genre']  # Rename the columns name

revenue_actor.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816 entries, 0 to 815
# Data columns (total 2 columns):
# revenues    816 non-null float64
# genre       816 non-null object
# dtypes: float64(1), object(1)
# memory usage: 19.1+ KB
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#    revenues in mil                      genre
# 0              188   Action, Adventure, Drama
# 1               26          Mystery, Thriller
# 2               30              Comedy, Crime
# 3                4                      Drama
# 4              157  Action, Adventure, Sci-Fi

# %% [markdown]
# The above code shows that using Revenues in Million in integer format as number of transaction is preferred. There are 298 unique revenue number out of 895 of total rows
#
# Consolidate the items into 1 transaction per row with each revenue number, in this case revenues in million

# %%
# Group actor by revenue generated (298 unique revenue number) 

basket = revenue_actor.groupby(['revenues in mil'])['genre'].apply(list)

print("\n", basket[:6])
# Out:
#  revenues in mil
# 0    [Action, Crime, Thriller, Crime, Drama, Myster...
# 1    [Drama, Mystery, Sci-Fi, Action, Drama, Sci-Fi...
# 2    [Crime, Drama, Crime, Drama, Comedy, Romance, ...
# 3                                     [Drama, Romance]
# 4    [Drama, Crime, Drama, Musical, Comedy, Drama, ...
# 5    [Drama, Thriller, Animation, Adventure, Family...
# Name: genre, dtype: object

# %%
# List all the actor in list format (for model preparation)

basket_list = list(basket)

print("\n", basket_list[:10])
# Out:
#  [['Action, Crime, Thriller', 'Crime, Drama, Mystery', 'Action, Crime, Drama', 'Crime, Drama, Sport', 'Adventure, Comedy, Sci-Fi', 'Drama', 'Drama, Fantasy, Romance', 'Comedy, Horror', 'Action, Adventure, Drama'], ['Drama, Mystery, Sci-Fi', 'Action, Drama, Sci-Fi', 'Action, Drama, Mystery', 'Drama, Thriller', 'Drama, Thriller', 'Drama'], ['Crime, Drama', 'Crime, Drama', 'Comedy, Romance, Sport', 'Drama, Horror, Romance', 'Biography, Crime, Drama'], ['Drama, Romance'], ['Drama', 'Crime, Drama, Musical', 'Comedy, Drama, Romance', 'Action, Comedy, Crime', 'Sci-Fi, Thriller'], ['Drama, Thriller', 'Animation, Adventure, Family', 'Drama, Mystery, Sci-Fi', 'Action, Drama, Sci-Fi', 'Animation, Drama, Fantasy'], ['Comedy, Drama', 'Biography, Drama, History', 'Drama, Romance', 'Action, Crime, Thriller', 'Drama, Mystery, Romance', 'Action, Adventure, Comedy', 'Comedy, Drama'], ['Drama, Mystery, Thriller', 'Comedy, Drama', 'Drama'], ['Crime, Drama', 'Comedy, Crime, Drama'], ['Comedy, Drama, Romance']]

# %% [markdown]
# ### 3) Convert list to dataframe with Boolean values

# %%
# Convert list to dataframe with Boolean values

te = TransactionEncoder()
te_ary = te.fit(basket_list).transform(basket_list)

df2 = pd.DataFrame(te_ary, columns=te.columns_)
df2.head(10)
# Out:
#    Action, Adventure  Action, Adventure, Biography  Action, Adventure, Comedy  \
# 0              False                         False                      False
# 1              False                         False                      False
# 2              False                         False                      False
# 3              False                         False                      False
# 4              False                         False                      False
# 5              False                         False                      False
# 6              False                         False                       True
# 7              False                         False                      False
# 8              False                         False                      False
# 9              False                         False                      False
#
#    Action, Adventure, Crime  Action, Adventure, Drama  \
# 0                     False                      True
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
# 5                     False                     False
# 6                     False                     False
# 7                     False                     False
# 8                     False                     False
# 9                     False                     False
#
#    Action, Adventure, Family  Action, Adventure, Fantasy  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
# 5                      False                       False
# 6                      False                       False
# 7                      False                       False
# 8                      False                       False
# 9                      False                       False
#
#    Action, Adventure, History  Action, Adventure, Horror  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# 5                       False                      False
# 6                       False                      False
# 7                       False                      False
# 8                       False                      False
# 9                       False                      False
#
#    Action, Adventure, Mystery  ...  Horror  Horror, Mystery  \
# 0                       False  ...   False            False
# 1                       False  ...   False            False
# 2                       False  ...   False            False
# 3                       False  ...   False            False
# 4                       False  ...   False            False
# 5                       False  ...   False            False
# 6                       False  ...   False            False
# 7                       False  ...   False            False
# 8                       False  ...   False            False
# 9                       False  ...   False            False
#
#    Horror, Mystery, Thriller  Horror, Sci-Fi  Horror, Sci-Fi, Thriller  \
# 0                      False           False                     False
# 1                      False           False                     False
# 2                      False           False                     False
# 3                      False           False                     False
# 4                      False           False                     False
# 5                      False           False                     False
# 6                      False           False                     False
# 7                      False           False                     False
# 8                      False           False                     False
# 9                      False           False                     False
#
#    Horror, Thriller  Mystery, Sci-Fi, Thriller  Mystery, Thriller  \
# 0             False                      False              False
# 1             False                      False              False
# 2             False                      False              False
# 3             False                      False              False
# 4             False                      False              False
# 5             False                      False              False
# 6             False                      False              False
# 7             False                      False              False
# 8             False                      False              False
# 9             False                      False              False
#
#    Romance, Sci-Fi, Thriller  Sci-Fi, Thriller
# 0                      False             False
# 1                      False             False
# 2                      False             False
# 3                      False             False
# 4                      False              True
# 5                      False             False
# 6                      False             False
# 7                      False             False
# 8                      False             False
# 9                      False             False
#
# [10 rows x 157 columns]

# %% [markdown]
# The above table shows the distribution of each movie genre in one revenue number. False indicates no genre by the specific revenue number whereas True indicates that the movie genre generating the specific revenue number.

# %% [markdown]
# ### 4) Find frequently occurring itemsets using Apriori Algorithm
#
# `Apriori` is an algorithm for frequent itemset mining and association rule learning over relational databases. Apriori is an algorithm for frequent itemset mining and Association Rule learning over relational databases. The algorithm identify the frequent individual items in the database and extending them to larger and larger itemsets as long as those itemsets appear sufficiently often in the database.
#
# The frequent itemsets determined by `Apriori` can be used to determine `Association Rules` which highlight general trends in the database. This has applications in domains such as market basket analysis.
#
# The `Support` and `Confidence` are measures to measure how interesting a rule is. These parameters are used to exclude rules in the result that have a `Support` or a `Confidence` lower than the minimum support and minimum confidence respectively. I have experimented a number trial of minimum support number and 0.01 is the best for this dataset.

# %% [markdown]
# 1)	Pros: Easy to code up
#
# 2)	Cons: May be slow on large datasets
#
# 3)	Works with: Numeric values, nominal values
#
#
# #### General approach to Apriori algorithm:
#
#     1)	Preparation: Any data type will work because we storing sets.
#     2)	Train: Use the Apriori algorithm to find frequent itemsets.
#     3)	Test: Doesn’t apply.
#     4)	Application: This will be used to find frequent itemsets and association rules between items.

# %%
# Frequently occurring itemsets using Apriori Algorithm

frequent_itemsets_apriori = apriori(df2, min_support=0.01, 
                                    use_colnames=True).sort_values(by='support', ascending=0)
frequent_itemsets_apriori
# Out:
#       support                                           itemsets
# 7    0.204698                        (Action, Adventure, Sci-Fi)
# 31   0.117450                     (Animation, Adventure, Comedy)
# 5    0.097315                       (Action, Adventure, Fantasy)
# 39   0.083893                                           (Comedy)
# 45   0.080537                           (Comedy, Drama, Romance)
# 3    0.070470                         (Action, Adventure, Drama)
# 1    0.070470                        (Action, Adventure, Comedy)
# 51   0.057047                           (Crime, Drama, Thriller)
# 10   0.057047                            (Action, Comedy, Crime)
# 48   0.057047                                  (Comedy, Romance)
# 13   0.057047                          (Action, Crime, Thriller)
# 42   0.053691                                    (Comedy, Drama)
# 61   0.053691                                   (Drama, Romance)
# 8    0.053691                      (Action, Adventure, Thriller)
# 11   0.050336                             (Action, Crime, Drama)
# 53   0.050336                                            (Drama)
# 50   0.043624                            (Crime, Drama, Mystery)
# 24   0.043624                                 (Action, Thriller)
# 29   0.040268                       (Adventure, Family, Fantasy)
# 35   0.036913                          (Biography, Crime, Drama)
# 68   0.036913                        (Horror, Mystery, Thriller)
# 28   0.033557                        (Adventure, Drama, Fantasy)
# 36   0.033557                                 (Biography, Drama)
# 16   0.033557                            (Action, Drama, Sci-Fi)
# 37   0.033557                        (Biography, Drama, History)
# 59   0.030201                           (Drama, Mystery, Sci-Fi)
# 43   0.026846                           (Comedy, Drama, Fantasy)
# 4    0.026846                        (Action, Adventure, Family)
# 89   0.023490     (Action, Crime, Drama, Comedy, Drama, Romance)
# 65   0.023490                                  (Drama, Thriller)
# ..        ...                                                ...
# 105  0.010067     (Comedy, Crime, Drama, Comedy, Drama, Romance)
# 106  0.010067            (Drama, Mystery, Sci-Fi, Comedy, Drama)
# 108  0.010067   (Comedy, Drama, Romance, Crime, Drama, Thriller)
# 110  0.010067  (Comedy, Drama, Romance, Horror, Mystery, Thri...
# 111  0.010067           (Comedy, Romance, Crime, Drama, Mystery)
# 90   0.010067  (Action, Crime, Drama, Horror, Mystery, Thriller)
# 56   0.010067                           (Drama, Horror, Mystery)
# 88   0.010067          (Action, Adventure, Sci-Fi, Drama, Sport)
# 57   0.010067                                     (Drama, Music)
# 9    0.010067                         (Action, Biography, Drama)
# 12   0.010067                            (Action, Crime, Sci-Fi)
# 18   0.010067                          (Action, Fantasy, Horror)
# 19   0.010067                        (Action, Fantasy, Thriller)
# 25   0.010067                         (Adventure, Comedy, Drama)
# 27   0.010067                        (Adventure, Comedy, Sci-Fi)
# 34   0.010067                         (Biography, Comedy, Drama)
# 44   0.010067                             (Comedy, Drama, Music)
# 46   0.010067                          (Comedy, Family, Fantasy)
# 58   0.010067                          (Drama, Mystery, Romance)
# 86   0.010067       (Action, Adventure, Sci-Fi, Comedy, Romance)
# 62   0.010067                           (Drama, Romance, Sci-Fi)
# 72   0.010067  (Action, Crime, Thriller, Action, Adventure, C...
# 75   0.010067  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 76   0.010067   (Action, Crime, Drama, Action, Adventure, Drama)
# 77   0.010067  (Comedy, Drama, Romance, Action, Adventure, Fa...
# 79   0.010067  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 83   0.010067      (Action, Adventure, Sci-Fi, Biography, Drama)
# 84   0.010067                (Action, Adventure, Sci-Fi, Comedy)
# 85   0.010067         (Action, Adventure, Sci-Fi, Comedy, Drama)
# 112  0.010067  (Comedy, Drama, Action, Adventure, Comedy, Com...
#
# [113 rows x 2 columns]

# %% [markdown]
# ### 5) Find frequently occurring itemsets using F-P Growth (Frequent Pattern Growth)
#
# 1) Pros: Usually faster than Apriori.
#
# 2) Cons: Difficult to implement; certain datasets degrade the performance.
#
# 3) Works with Nominal values.

# %% [markdown]
# #### General approach to FP-growth algorithm
#
#     1) Preparation: Discrete data is needed because we’re storing sets. For continuous data, it will need to be
#     quantized into discrete values.
#     2) Train: Build an FP-tree and mine the tree.
#     3) Test: Doesn’t apply.
#     4) Application: This can be used to identify commonly occurring items that can be used to make decisions,
#     suggest items, make forecasts, and so on.

# %% [markdown]
# The frequently occurring movie genre using F-P Growth as follows:

# %%
# Frequently occurring itemsets using F-P Growth (Frequent Pattern Growth)

frequent_itemsets_fpgrowth = fpgrowth(df2, min_support=0.01, 
                                     use_colnames=True).sort_values(by='support', ascending=0)
frequent_itemsets_fpgrowth
# Out:
#       support                                           itemsets
# 39   0.204698                        (Action, Adventure, Sci-Fi)
# 37   0.117450                     (Animation, Adventure, Comedy)
# 45   0.097315                       (Action, Adventure, Fantasy)
# 33   0.083893                                           (Comedy)
# 15   0.080537                           (Comedy, Drama, Romance)
# 0    0.070470                         (Action, Adventure, Drama)
# 18   0.070470                        (Action, Adventure, Comedy)
# 1    0.057047                          (Action, Crime, Thriller)
# 32   0.057047                           (Crime, Drama, Thriller)
# 16   0.057047                            (Action, Comedy, Crime)
# 44   0.057047                                  (Comedy, Romance)
# 14   0.053691                                   (Drama, Romance)
# 63   0.053691                      (Action, Adventure, Thriller)
# 19   0.053691                                    (Comedy, Drama)
# 2    0.050336                             (Action, Crime, Drama)
# 3    0.050336                                            (Drama)
# 4    0.043624                            (Crime, Drama, Mystery)
# 38   0.043624                                 (Action, Thriller)
# 48   0.040268                       (Adventure, Family, Fantasy)
# 29   0.036913                        (Horror, Mystery, Thriller)
# 12   0.036913                          (Biography, Crime, Drama)
# 8    0.033557                            (Action, Drama, Sci-Fi)
# 34   0.033557                                 (Biography, Drama)
# 60   0.033557                        (Adventure, Drama, Fantasy)
# 20   0.033557                        (Biography, Drama, History)
# 9    0.030201                           (Drama, Mystery, Sci-Fi)
# 30   0.026846                           (Comedy, Drama, Fantasy)
# 51   0.026846                        (Action, Adventure, Family)
# 105  0.023490  (Animation, Adventure, Comedy, Action, Adventu...
# 61   0.023490                        (Action, Mystery, Thriller)
# ..        ...                                                ...
# 98   0.010067                            (Comedy, Crime, Comedy)
# 99   0.010067   (Comedy, Drama, Romance, Crime, Drama, Thriller)
# 106  0.010067        (Action, Crime, Thriller, Action, Thriller)
# 100  0.010067                (Action, Adventure, Sci-Fi, Comedy)
# 102  0.010067                  (Biography, Drama, Comedy, Drama)
# 94   0.010067     (Comedy, Crime, Drama, Comedy, Drama, Romance)
# 56   0.010067                        (Action, Fantasy, Thriller)
# 84   0.010067                           (Drama, Romance, Comedy)
# 58   0.010067                          (Action, Fantasy, Horror)
# 7    0.010067                        (Adventure, Comedy, Sci-Fi)
# 21   0.010067                          (Drama, Mystery, Romance)
# 24   0.010067                         (Adventure, Comedy, Drama)
# 25   0.010067                                     (Drama, Music)
# 26   0.010067                            (Action, Crime, Sci-Fi)
# 27   0.010067                         (Biography, Comedy, Drama)
# 35   0.010067                           (Drama, Horror, Mystery)
# 41   0.010067                           (Drama, Romance, Sci-Fi)
# 43   0.010067                             (Comedy, Drama, Music)
# 59   0.010067                         (Action, Biography, Drama)
# 82   0.010067          (Action, Crime, Thriller, Drama, Romance)
# 64   0.010067                          (Comedy, Family, Fantasy)
# 70   0.010067                                (Action, Adventure)
# 71   0.010067  (Action, Adventure, Sci-Fi, Action, Adventure,...
# 72   0.010067  (Action, Crime, Thriller, Action, Adventure, C...
# 73   0.010067         (Action, Crime, Thriller, Comedy, Romance)
# 74   0.010067  (Action, Adventure, Sci-Fi, Action, Crime, Thr...
# 75   0.010067   (Action, Crime, Drama, Action, Adventure, Drama)
# 78   0.010067           (Comedy, Romance, Crime, Drama, Mystery)
# 80   0.010067            (Drama, Mystery, Sci-Fi, Comedy, Drama)
# 112  0.010067  (Comedy, Drama, Romance, Action, Adventure, Fa...
#
# [113 rows x 2 columns]

# %% [markdown]
# ### 6) Mine the Association Rules
#
# Association rules analysis is a technique to uncover how items are associated to each other. There are 3 common ways to measure association:
#
# 1) Measure 1: `Support` - This says how popular an itemset is, as measured by the proportion of transactions in which an itemset appears. If we discover that sales of certain items beyond a certain proportion or tend to have a significant impact on our profits, we might consider using that proportion as your `support` threshold. Thus, we identify itemsets with `support values above this threshold` as significant itemsets.
#
# 2) Measure 2: `Confidence`. This says how likely item B is purchased when item A is purchased, expressed as {A -> B}. This is measured by the proportion of transactions with item A, in which item B also appears. One drawback of the `confidence` measure is that it might misrepresent the importance of an association. This is because it only accounts for how popular A are, but not B. If B are also very popular in general, there will be a higher chance that a transaction containing A will also contain B, thus inflating the confidence measure. To account for the base popularity of both constituent items, we use a third measure called `Lift`.
#
# 3) Measure 3: `Lift`. This says how likely item B is purchased when item A is purchased, while controlling for how popular item B is.
#
#     a)Lift of {A -> B} = 1, means no association between items.
#     b)Lift {A -> B} > 1, means that item B is likely to be bought if item A is bought,
#     c)Lift {A -> B} < 1, means that item B is unlikely to be bought if item A is bought.

# %% [markdown]
# Now I want to build our association rules. Apyori's apriori function accepts a number of arguments, mainly:
#
#     a)transaction: list of list of items in transactions (eg. [['A', 'B'], ['B', 'C']]).
#     b)min_support: Minimum support of relations in float percentage. Default 0.003.
#     c)min_confidence: Minimum confidence of relations in float percentage. Default 0.0.
#     d)min_lift: Minimum lift of relations in float percentage. Default 0.0.
#     e)max_length: Max length of the relations. Default None.

# %% [markdown]
# #### 6a) Mine the Association Rules using Apriori Algorithm

# %%
# Generate the Association Rules using Apriori Algorithm with their corresponding support, confidence and lift. 

rules_apriori = association_rules(frequent_itemsets_apriori, metric="lift", min_threshold=1)
rules_apriori = rules_apriori.sort_values(by='lift', ascending=0)

# %%
# View top 10 rules 

rules_apriori
# Out:
#                                    antecedents  \
# 71                             (Comedy, Drama)
# 70         (Action, Adventure, Comedy, Comedy)
# 69                     (Comedy, Drama, Comedy)
# 72                 (Action, Adventure, Comedy)
# 47                    (Comedy, Drama, Romance)
# 46                      (Comedy, Crime, Drama)
# 49                             (Comedy, Drama)
# 48                    (Drama, Mystery, Sci-Fi)
# 68  (Action, Adventure, Comedy, Comedy, Drama)
# 44                             (Comedy, Crime)
# 73                                    (Comedy)
# 45                                    (Comedy)
# 1                     (Comedy, Drama, Romance)
# 0                       (Action, Crime, Drama)
# 37                             (Comedy, Drama)
# 36                          (Biography, Drama)
# 56                      (Action, Crime, Drama)
# 57                 (Horror, Mystery, Thriller)
# 5                              (Comedy, Drama)
# 4                  (Action, Adventure, Comedy)
# 40                          (Biography, Drama)
# 41                           (Comedy, Romance)
# 20                                     (Drama)
# 21                   (Action, Crime, Thriller)
# 18                             (Comedy, Drama)
# 19                            (Drama, Romance)
# 65                 (Action, Adventure, Family)
# 64                    (Comedy, Drama, Romance)
# 54                           (Comedy, Romance)
# 55                     (Crime, Drama, Mystery)
# ..                                         ...
# 17                            (Drama, Romance)
# 16                    (Comedy, Drama, Romance)
# 25                           (Comedy, Romance)
# 24                   (Action, Crime, Thriller)
# 12                             (Comedy, Drama)
# 13                                    (Comedy)
# 63                  (Action, Adventure, Drama)
# 10                 (Action, Adventure, Comedy)
# 11                                    (Comedy)
# 62                      (Action, Crime, Drama)
# 61                 (Action, Adventure, Comedy)
# 60                   (Action, Crime, Thriller)
# 35                                    (Comedy)
# 34                            (Drama, Romance)
# 51                    (Crime, Drama, Thriller)
# 50                    (Comedy, Drama, Romance)
# 28                (Adventure, Family, Fantasy)
# 29              (Animation, Adventure, Comedy)
# 6                 (Adventure, Family, Fantasy)
# 7                  (Action, Adventure, Sci-Fi)
# 22                    (Comedy, Drama, Romance)
# 23                                    (Comedy)
# 9                           (Action, Thriller)
# 8                  (Action, Adventure, Sci-Fi)
# 15                     (Crime, Drama, Mystery)
# 14                 (Action, Adventure, Sci-Fi)
# 67                          (Biography, Drama)
# 66                 (Action, Adventure, Sci-Fi)
# 3                  (Action, Adventure, Comedy)
# 2                  (Action, Adventure, Sci-Fi)
#
#                                    consequents  antecedent support  \
# 71         (Action, Adventure, Comedy, Comedy)            0.053691
# 70                             (Comedy, Drama)            0.016779
# 69                 (Action, Adventure, Comedy)            0.013423
# 72                     (Comedy, Drama, Comedy)            0.070470
# 47                      (Comedy, Crime, Drama)            0.080537
# 46                    (Comedy, Drama, Romance)            0.020134
# 49                    (Drama, Mystery, Sci-Fi)            0.053691
# 48                             (Comedy, Drama)            0.030201
# 68                                    (Comedy)            0.020134
# 44                                    (Comedy)            0.020134
# 73  (Action, Adventure, Comedy, Comedy, Drama)            0.083893
# 45                             (Comedy, Crime)            0.083893
# 1                       (Action, Crime, Drama)            0.080537
# 0                     (Comedy, Drama, Romance)            0.050336
# 37                          (Biography, Drama)            0.053691
# 36                             (Comedy, Drama)            0.033557
# 56                 (Horror, Mystery, Thriller)            0.050336
# 57                      (Action, Crime, Drama)            0.036913
# 5                  (Action, Adventure, Comedy)            0.053691
# 4                              (Comedy, Drama)            0.070470
# 40                           (Comedy, Romance)            0.033557
# 41                          (Biography, Drama)            0.057047
# 20                   (Action, Crime, Thriller)            0.050336
# 21                                     (Drama)            0.057047
# 18                            (Drama, Romance)            0.053691
# 19                             (Comedy, Drama)            0.053691
# 65                    (Comedy, Drama, Romance)            0.026846
# 64                 (Action, Adventure, Family)            0.080537
# 54                     (Crime, Drama, Mystery)            0.057047
# 55                           (Comedy, Romance)            0.043624
# ..                                         ...                 ...
# 17                    (Comedy, Drama, Romance)            0.053691
# 16                            (Drama, Romance)            0.080537
# 25                   (Action, Crime, Thriller)            0.057047
# 24                           (Comedy, Romance)            0.057047
# 12                                    (Comedy)            0.053691
# 13                             (Comedy, Drama)            0.083893
# 63                      (Action, Crime, Drama)            0.070470
# 10                                    (Comedy)            0.070470
# 11                 (Action, Adventure, Comedy)            0.083893
# 62                  (Action, Adventure, Drama)            0.050336
# 61                   (Action, Crime, Thriller)            0.070470
# 60                 (Action, Adventure, Comedy)            0.057047
# 35                            (Drama, Romance)            0.083893
# 34                                    (Comedy)            0.053691
# 51                    (Comedy, Drama, Romance)            0.057047
# 50                    (Crime, Drama, Thriller)            0.080537
# 28              (Animation, Adventure, Comedy)            0.040268
# 29                (Adventure, Family, Fantasy)            0.117450
# 6                  (Action, Adventure, Sci-Fi)            0.040268
# 7                 (Adventure, Family, Fantasy)            0.204698
# 22                                    (Comedy)            0.080537
# 23                    (Comedy, Drama, Romance)            0.083893
# 9                  (Action, Adventure, Sci-Fi)            0.043624
# 8                           (Action, Thriller)            0.204698
# 15                 (Action, Adventure, Sci-Fi)            0.043624
# 14                     (Crime, Drama, Mystery)            0.204698
# 67                 (Action, Adventure, Sci-Fi)            0.033557
# 66                          (Biography, Drama)            0.204698
# 3                  (Action, Adventure, Sci-Fi)            0.070470
# 2                  (Action, Adventure, Comedy)            0.204698
#
#     consequent support   support  confidence       lift  leverage  conviction
# 71            0.016779  0.010067    0.187500  11.175000  0.009166    1.210119
# 70            0.053691  0.010067    0.600000  11.175000  0.009166    2.365772
# 69            0.070470  0.010067    0.750000  10.642857  0.009121    3.718121
# 72            0.013423  0.010067    0.142857  10.642857  0.009121    1.151007
# 47            0.020134  0.010067    0.125000   6.208333  0.008446    1.119847
# 46            0.080537  0.010067    0.500000   6.208333  0.008446    1.838926
# 49            0.030201  0.010067    0.187500   6.208333  0.008446    1.193598
# 48            0.053691  0.010067    0.333333   6.208333  0.008446    1.419463
# 68            0.083893  0.010067    0.500000   5.960000  0.008378    1.832215
# 44            0.083893  0.010067    0.500000   5.960000  0.008378    1.832215
# 73            0.020134  0.010067    0.120000   5.960000  0.008378    1.113484
# 45            0.020134  0.010067    0.120000   5.960000  0.008378    1.113484
# 1             0.050336  0.023490    0.291667   5.794444  0.019436    1.340703
# 0             0.080537  0.023490    0.466667   5.794444  0.019436    1.723993
# 37            0.033557  0.010067    0.187500   5.587500  0.008265    1.189468
# 36            0.053691  0.010067    0.300000   5.587500  0.008265    1.351870
# 56            0.036913  0.010067    0.200000   5.418182  0.008209    1.203859
# 57            0.050336  0.010067    0.272727   5.418182  0.008209    1.305789
# 5             0.070470  0.020134    0.375000   5.321429  0.016351    1.487248
# 4             0.053691  0.020134    0.285714   5.321429  0.016351    1.324832
# 40            0.057047  0.010067    0.300000   5.258824  0.008153    1.347076
# 41            0.033557  0.010067    0.176471   5.258824  0.008153    1.173538
# 20            0.057047  0.013423    0.266667   4.674510  0.010551    1.285845
# 21            0.050336  0.013423    0.235294   4.674510  0.010551    1.241869
# 18            0.053691  0.013423    0.250000   4.656250  0.010540    1.261745
# 19            0.053691  0.013423    0.250000   4.656250  0.010540    1.261745
# 65            0.080537  0.010067    0.375000   4.656250  0.007905    1.471141
# 64            0.026846  0.010067    0.125000   4.656250  0.007905    1.112176
# 54            0.043624  0.010067    0.176471   4.045249  0.007578    1.161314
# 55            0.057047  0.010067    0.230769   4.045249  0.007578    1.225839
# ..                 ...       ...         ...        ...       ...         ...
# 17            0.080537  0.013423    0.250000   3.104167  0.009099    1.225951
# 16            0.053691  0.013423    0.166667   3.104167  0.009099    1.135570
# 25            0.057047  0.010067    0.176471   3.093426  0.006813    1.145014
# 24            0.057047  0.010067    0.176471   3.093426  0.006813    1.145014
# 12            0.083893  0.013423    0.250000   2.980000  0.008919    1.221477
# 13            0.053691  0.013423    0.160000   2.980000  0.008919    1.126558
# 63            0.050336  0.010067    0.142857   2.838095  0.006520    1.107942
# 10            0.083893  0.016779    0.238095   2.838095  0.010867    1.202391
# 11            0.070470  0.016779    0.200000   2.838095  0.010867    1.161913
# 62            0.070470  0.010067    0.200000   2.838095  0.006520    1.161913
# 61            0.057047  0.010067    0.142857   2.504202  0.006047    1.100112
# 60            0.070470  0.010067    0.176471   2.504202  0.006047    1.128715
# 35            0.053691  0.010067    0.120000   2.235000  0.005563    1.075351
# 34            0.083893  0.010067    0.187500   2.235000  0.005563    1.127517
# 51            0.080537  0.010067    0.176471   2.191176  0.005473    1.116491
# 50            0.057047  0.010067    0.125000   2.191176  0.005473    1.077661
# 28            0.117450  0.010067    0.250000   2.128571  0.005338    1.176734
# 29            0.040268  0.010067    0.085714   2.128571  0.005338    1.049706
# 6             0.204698  0.016779    0.416667   2.035519  0.008536    1.363375
# 7             0.040268  0.016779    0.081967   2.035519  0.008536    1.045422
# 22            0.083893  0.013423    0.166667   1.986667  0.006666    1.099329
# 23            0.080537  0.013423    0.160000   1.986667  0.006666    1.094599
# 9             0.204698  0.016779    0.384615   1.878941  0.007849    1.292366
# 8             0.043624  0.016779    0.081967   1.878941  0.007849    1.041767
# 15            0.204698  0.013423    0.307692   1.503153  0.004493    1.148770
# 14            0.043624  0.013423    0.065574   1.503153  0.004493    1.023490
# 67            0.204698  0.010067    0.300000   1.465574  0.003198    1.136146
# 66            0.033557  0.010067    0.049180   1.465574  0.003198    1.016431
# 3             0.204698  0.020134    0.285714   1.395785  0.005709    1.113423
# 2             0.070470  0.020134    0.098361   1.395785  0.005709    1.030933
#
# [74 rows x 9 columns]

# %% [markdown]
# `Antecedent` and a `Consequent`, both of which are a list of genres. Note that implication here is co-occurrence and not causality.

# %% [markdown]
# The maximum value of `Lift` is `11.1` and maximum value for `Confidence` is `0.75` found in `Association Rules using Apriori Algorithm`. I want to view for a large value of `Lift` and `Conficence` with range value of more than 1 and more than 0.4 repectively. This means that genre B is likely to be chosen if genre A is chosen

# %%
# Filter the dataframe for Lift > 1 and high confidence >= 0.5

rules_apriori[(rules_apriori['lift'] > 1) & 
              (rules_apriori['confidence'] >= 0.5)].sort_values(by='lift', ascending=0)
# Out:
#                                    antecedents                  consequents  \
# 70         (Action, Adventure, Comedy, Comedy)              (Comedy, Drama)
# 69                     (Comedy, Drama, Comedy)  (Action, Adventure, Comedy)
# 46                      (Comedy, Crime, Drama)     (Comedy, Drama, Romance)
# 68  (Action, Adventure, Comedy, Comedy, Drama)                     (Comedy)
# 44                             (Comedy, Crime)                     (Comedy)
# 59                              (Drama, Sport)  (Action, Adventure, Sci-Fi)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 70            0.016779            0.053691  0.010067        0.60  11.175000
# 69            0.013423            0.070470  0.010067        0.75  10.642857
# 46            0.020134            0.080537  0.010067        0.50   6.208333
# 68            0.020134            0.083893  0.010067        0.50   5.960000
# 44            0.020134            0.083893  0.010067        0.50   5.960000
# 59            0.013423            0.204698  0.010067        0.75   3.663934
#
#     leverage  conviction
# 70  0.009166    2.365772
# 69  0.009121    3.718121
# 46  0.008446    1.838926
# 68  0.008378    1.832215
# 44  0.008378    1.832215
# 59  0.007319    3.181208

# %% [markdown]
# Now I want to view small value of `Lift` and `Confidence` with range value of less than 1 and more than 0.4 respectively. This means that genre B is unlikely to be chosen if genre A is chosen

# %%
# Filter the dataframe for Lift < 1 and high confidence >= 0.5

rules_apriori[(rules_apriori['lift'] < 1) & 
              (rules_apriori['confidence'] >= 0.5)].sort_values(by='lift', ascending=0)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
# Filter the dataframe for Lift = 1 and high confidence > 0.5

rules_apriori[(rules_apriori['lift'] == 1) & 
              (rules_apriori['confidence'] >= 0.5)].sort_values(by='lift', ascending=0)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# Findings 1:
#
# 1) About 74 rules have a high Lift value (more than 1), which means that it increase the chances of occurence of movie genre in `Consequents` in spite high `Confidence` value.
#
# 2) A value of `Lift` which greater than 1 indicate for high association between `Antecedents` and `Consequents`. The greater the value of `Lift`, the greater are the chances of preference to choose genre in `Consequents`. Here, if the viewer has already watched movie with genre of (Comedy, Action, Adventure, Comedy), viewer will likely watch (Comedy, Drama) movie genre.
#
# 3) Comedy genre has high `Lift` value
#
# 4) `Lift` is the measure that will help movie producer to decide what kind of movie genre to produce next based on revenue generated from an individual movie.
#
# 5) These 74 rules also have wide range of `Confidence` number, range between 0.04 to 0.75.
#
# 6) There is no Association Rule for Lift value less than 1

# %% [markdown]
# #### 6b) Mine the Association Rules using F-P Growth

# %%
rules_fpgrowth = association_rules(frequent_itemsets_fpgrowth, metric="lift", min_threshold=1)
rules_fpgrowth = rules_fpgrowth.sort_values(by='lift', ascending=0)

# %%
rules_fpgrowth
# Out:
#                                    antecedents  \
# 32         (Action, Adventure, Comedy, Comedy)
# 33                             (Comedy, Drama)
# 31                     (Comedy, Drama, Comedy)
# 34                 (Action, Adventure, Comedy)
# 57                    (Comedy, Drama, Romance)
# 56                      (Comedy, Crime, Drama)
# 71                             (Comedy, Drama)
# 70                    (Drama, Mystery, Sci-Fi)
# 48                             (Comedy, Crime)
# 30  (Action, Adventure, Comedy, Comedy, Drama)
# 35                                    (Comedy)
# 49                                    (Comedy)
# 1                     (Comedy, Drama, Romance)
# 0                       (Action, Crime, Drama)
# 54                          (Biography, Drama)
# 55                             (Comedy, Drama)
# 47                 (Horror, Mystery, Thriller)
# 46                      (Action, Crime, Drama)
# 5                              (Comedy, Drama)
# 4                  (Action, Adventure, Comedy)
# 36                          (Biography, Drama)
# 37                           (Comedy, Romance)
# 12                                     (Drama)
# 13                   (Action, Crime, Thriller)
# 73                 (Action, Adventure, Family)
# 17                            (Drama, Romance)
# 72                    (Comedy, Drama, Romance)
# 16                             (Comedy, Drama)
# 53                          (Action, Thriller)
# 52                   (Action, Crime, Thriller)
# ..                                         ...
# 18                    (Comedy, Drama, Romance)
# 19                            (Drama, Romance)
# 65                           (Comedy, Romance)
# 64                   (Action, Crime, Thriller)
# 20                             (Comedy, Drama)
# 21                                    (Comedy)
# 67                  (Action, Adventure, Drama)
# 66                      (Action, Crime, Drama)
# 9                                     (Comedy)
# 8                  (Action, Adventure, Comedy)
# 62                   (Action, Crime, Thriller)
# 63                 (Action, Adventure, Comedy)
# 58                            (Drama, Romance)
# 59                                    (Comedy)
# 51                    (Crime, Drama, Thriller)
# 50                    (Comedy, Drama, Romance)
# 29              (Animation, Adventure, Comedy)
# 28                (Adventure, Family, Fantasy)
# 7                  (Action, Adventure, Sci-Fi)
# 6                 (Adventure, Family, Fantasy)
# 22                    (Comedy, Drama, Romance)
# 23                                    (Comedy)
# 10                 (Action, Adventure, Sci-Fi)
# 11                          (Action, Thriller)
# 15                     (Crime, Drama, Mystery)
# 14                 (Action, Adventure, Sci-Fi)
# 39                          (Biography, Drama)
# 38                 (Action, Adventure, Sci-Fi)
# 3                  (Action, Adventure, Comedy)
# 2                  (Action, Adventure, Sci-Fi)
#
#                                    consequents  antecedent support  \
# 32                             (Comedy, Drama)            0.016779
# 33         (Action, Adventure, Comedy, Comedy)            0.053691
# 31                 (Action, Adventure, Comedy)            0.013423
# 34                     (Comedy, Drama, Comedy)            0.070470
# 57                      (Comedy, Crime, Drama)            0.080537
# 56                    (Comedy, Drama, Romance)            0.020134
# 71                    (Drama, Mystery, Sci-Fi)            0.053691
# 70                             (Comedy, Drama)            0.030201
# 48                                    (Comedy)            0.020134
# 30                                    (Comedy)            0.020134
# 35  (Action, Adventure, Comedy, Comedy, Drama)            0.083893
# 49                             (Comedy, Crime)            0.083893
# 1                       (Action, Crime, Drama)            0.080537
# 0                     (Comedy, Drama, Romance)            0.050336
# 54                             (Comedy, Drama)            0.033557
# 55                          (Biography, Drama)            0.053691
# 47                      (Action, Crime, Drama)            0.036913
# 46                 (Horror, Mystery, Thriller)            0.050336
# 5                  (Action, Adventure, Comedy)            0.053691
# 4                              (Comedy, Drama)            0.070470
# 36                           (Comedy, Romance)            0.033557
# 37                          (Biography, Drama)            0.057047
# 12                   (Action, Crime, Thriller)            0.050336
# 13                                     (Drama)            0.057047
# 73                    (Comedy, Drama, Romance)            0.026846
# 17                             (Comedy, Drama)            0.053691
# 72                 (Action, Adventure, Family)            0.080537
# 16                            (Drama, Romance)            0.053691
# 53                   (Action, Crime, Thriller)            0.043624
# 52                          (Action, Thriller)            0.057047
# ..                                         ...                 ...
# 18                            (Drama, Romance)            0.080537
# 19                    (Comedy, Drama, Romance)            0.053691
# 65                   (Action, Crime, Thriller)            0.057047
# 64                           (Comedy, Romance)            0.057047
# 20                                    (Comedy)            0.053691
# 21                             (Comedy, Drama)            0.083893
# 67                      (Action, Crime, Drama)            0.070470
# 66                  (Action, Adventure, Drama)            0.050336
# 9                  (Action, Adventure, Comedy)            0.083893
# 8                                     (Comedy)            0.070470
# 62                 (Action, Adventure, Comedy)            0.057047
# 63                   (Action, Crime, Thriller)            0.070470
# 58                                    (Comedy)            0.053691
# 59                            (Drama, Romance)            0.083893
# 51                    (Comedy, Drama, Romance)            0.057047
# 50                    (Crime, Drama, Thriller)            0.080537
# 29                (Adventure, Family, Fantasy)            0.117450
# 28              (Animation, Adventure, Comedy)            0.040268
# 7                 (Adventure, Family, Fantasy)            0.204698
# 6                  (Action, Adventure, Sci-Fi)            0.040268
# 22                                    (Comedy)            0.080537
# 23                    (Comedy, Drama, Romance)            0.083893
# 10                          (Action, Thriller)            0.204698
# 11                 (Action, Adventure, Sci-Fi)            0.043624
# 15                 (Action, Adventure, Sci-Fi)            0.043624
# 14                     (Crime, Drama, Mystery)            0.204698
# 39                 (Action, Adventure, Sci-Fi)            0.033557
# 38                          (Biography, Drama)            0.204698
# 3                  (Action, Adventure, Sci-Fi)            0.070470
# 2                  (Action, Adventure, Comedy)            0.204698
#
#     consequent support   support  confidence       lift  leverage  conviction
# 32            0.053691  0.010067    0.600000  11.175000  0.009166    2.365772
# 33            0.016779  0.010067    0.187500  11.175000  0.009166    1.210119
# 31            0.070470  0.010067    0.750000  10.642857  0.009121    3.718121
# 34            0.013423  0.010067    0.142857  10.642857  0.009121    1.151007
# 57            0.020134  0.010067    0.125000   6.208333  0.008446    1.119847
# 56            0.080537  0.010067    0.500000   6.208333  0.008446    1.838926
# 71            0.030201  0.010067    0.187500   6.208333  0.008446    1.193598
# 70            0.053691  0.010067    0.333333   6.208333  0.008446    1.419463
# 48            0.083893  0.010067    0.500000   5.960000  0.008378    1.832215
# 30            0.083893  0.010067    0.500000   5.960000  0.008378    1.832215
# 35            0.020134  0.010067    0.120000   5.960000  0.008378    1.113484
# 49            0.020134  0.010067    0.120000   5.960000  0.008378    1.113484
# 1             0.050336  0.023490    0.291667   5.794444  0.019436    1.340703
# 0             0.080537  0.023490    0.466667   5.794444  0.019436    1.723993
# 54            0.053691  0.010067    0.300000   5.587500  0.008265    1.351870
# 55            0.033557  0.010067    0.187500   5.587500  0.008265    1.189468
# 47            0.050336  0.010067    0.272727   5.418182  0.008209    1.305789
# 46            0.036913  0.010067    0.200000   5.418182  0.008209    1.203859
# 5             0.070470  0.020134    0.375000   5.321429  0.016351    1.487248
# 4             0.053691  0.020134    0.285714   5.321429  0.016351    1.324832
# 36            0.057047  0.010067    0.300000   5.258824  0.008153    1.347076
# 37            0.033557  0.010067    0.176471   5.258824  0.008153    1.173538
# 12            0.057047  0.013423    0.266667   4.674510  0.010551    1.285845
# 13            0.050336  0.013423    0.235294   4.674510  0.010551    1.241869
# 73            0.080537  0.010067    0.375000   4.656250  0.007905    1.471141
# 17            0.053691  0.013423    0.250000   4.656250  0.010540    1.261745
# 72            0.026846  0.010067    0.125000   4.656250  0.007905    1.112176
# 16            0.053691  0.013423    0.250000   4.656250  0.010540    1.261745
# 53            0.057047  0.010067    0.230769   4.045249  0.007578    1.225839
# 52            0.043624  0.010067    0.176471   4.045249  0.007578    1.161314
# ..                 ...       ...         ...        ...       ...         ...
# 18            0.053691  0.013423    0.166667   3.104167  0.009099    1.135570
# 19            0.080537  0.013423    0.250000   3.104167  0.009099    1.225951
# 65            0.057047  0.010067    0.176471   3.093426  0.006813    1.145014
# 64            0.057047  0.010067    0.176471   3.093426  0.006813    1.145014
# 20            0.083893  0.013423    0.250000   2.980000  0.008919    1.221477
# 21            0.053691  0.013423    0.160000   2.980000  0.008919    1.126558
# 67            0.050336  0.010067    0.142857   2.838095  0.006520    1.107942
# 66            0.070470  0.010067    0.200000   2.838095  0.006520    1.161913
# 9             0.070470  0.016779    0.200000   2.838095  0.010867    1.161913
# 8             0.083893  0.016779    0.238095   2.838095  0.010867    1.202391
# 62            0.070470  0.010067    0.176471   2.504202  0.006047    1.128715
# 63            0.057047  0.010067    0.142857   2.504202  0.006047    1.100112
# 58            0.083893  0.010067    0.187500   2.235000  0.005563    1.127517
# 59            0.053691  0.010067    0.120000   2.235000  0.005563    1.075351
# 51            0.080537  0.010067    0.176471   2.191176  0.005473    1.116491
# 50            0.057047  0.010067    0.125000   2.191176  0.005473    1.077661
# 29            0.040268  0.010067    0.085714   2.128571  0.005338    1.049706
# 28            0.117450  0.010067    0.250000   2.128571  0.005338    1.176734
# 7             0.040268  0.016779    0.081967   2.035519  0.008536    1.045422
# 6             0.204698  0.016779    0.416667   2.035519  0.008536    1.363375
# 22            0.083893  0.013423    0.166667   1.986667  0.006666    1.099329
# 23            0.080537  0.013423    0.160000   1.986667  0.006666    1.094599
# 10            0.043624  0.016779    0.081967   1.878941  0.007849    1.041767
# 11            0.204698  0.016779    0.384615   1.878941  0.007849    1.292366
# 15            0.204698  0.013423    0.307692   1.503153  0.004493    1.148770
# 14            0.043624  0.013423    0.065574   1.503153  0.004493    1.023490
# 39            0.204698  0.010067    0.300000   1.465574  0.003198    1.136146
# 38            0.033557  0.010067    0.049180   1.465574  0.003198    1.016431
# 3             0.204698  0.020134    0.285714   1.395785  0.005709    1.113423
# 2             0.070470  0.020134    0.098361   1.395785  0.005709    1.030933
#
# [74 rows x 9 columns]

# %% [markdown]
# The maximum value of `Lift` is `11.1` and maximum value for `Confidence` is `0.75` found in `Association Rules using F-P Growth Algorithm` same like the `Apriori Algorithm`. I want to view for a large value of `Lift` and `Conficence` with range value of more than 1 and more than 0.4 respectively

# %%
# Filter the dataframe for Lift < 1 and high confidence >= 0.5

rules_fpgrowth[(rules_fpgrowth['lift'] > 1) & 
               (rules_fpgrowth['confidence'] >= 0.5)].sort_values(by='lift', ascending=0)
# Out:
#                                    antecedents                  consequents  \
# 32         (Action, Adventure, Comedy, Comedy)              (Comedy, Drama)
# 31                     (Comedy, Drama, Comedy)  (Action, Adventure, Comedy)
# 56                      (Comedy, Crime, Drama)     (Comedy, Drama, Romance)
# 48                             (Comedy, Crime)                     (Comedy)
# 30  (Action, Adventure, Comedy, Comedy, Drama)                     (Comedy)
# 43                              (Drama, Sport)  (Action, Adventure, Sci-Fi)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 32            0.016779            0.053691  0.010067        0.60  11.175000
# 31            0.013423            0.070470  0.010067        0.75  10.642857
# 56            0.020134            0.080537  0.010067        0.50   6.208333
# 48            0.020134            0.083893  0.010067        0.50   5.960000
# 30            0.020134            0.083893  0.010067        0.50   5.960000
# 43            0.013423            0.204698  0.010067        0.75   3.663934
#
#     leverage  conviction
# 32  0.009166    2.365772
# 31  0.009121    3.718121
# 56  0.008446    1.838926
# 48  0.008378    1.832215
# 30  0.008378    1.832215
# 43  0.007319    3.181208

# %%
# Filter the dataframe for Lift < 1 and high confidence >= 0.5

rules_apriori[(rules_apriori['lift'] < 1) & 
              (rules_apriori['confidence'] >= 0.5)].sort_values(by='lift', ascending=0)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
# Filter the dataframe for Lift = 1 and high confidence > 0.5

rules_apriori[(rules_apriori['lift'] == 1) & 
              (rules_apriori['confidence'] >= 0.5)].sort_values(by='lift', ascending=0)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# #### Findings 2:
#
# 1) The output from `F-P Growth algorithm` is same like `Apriori algorithm` for this case study. About 74 rule have a high `Lift` value (more than 1), which means that it increase the chances of occurence of movie genre in `Consequents` in spite high `Confidence` value.
#
# 2) These 74 rules of high `Lift` value also have wide range of `Confidence` number, range between 0.04 to 0.75.
#
# 3) `F-P Growth algorithm` showed faster in processing the data than `Apriori algorithm`
#
# 4) There is no Association Rule for Lift value less than 1 in this case study

# %%
rules_apriori.to_csv('Apriori_Revenues_Genre.csv',mode = 'w', index=False, header=True)

# %%
rules_fpgrowth.to_csv('FPGrowth_Revenues_Genre.csv',mode = 'w', index=False, header=True)
